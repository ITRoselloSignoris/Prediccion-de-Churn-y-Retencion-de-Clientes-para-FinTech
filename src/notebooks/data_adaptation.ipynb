# %%
from funpymodeling import status, freq_tbl
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("../datasets/raw_data/Churn_Modelling.csv")
dataset
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
status(dataset)
# Out:
#            variable  q_nan  p_nan  q_zeros  p_zeros  unique     type
# 0         RowNumber      0    0.0        0   0.0000   10000    int64
# 1        CustomerId      0    0.0        0   0.0000   10000    int64
# 2           Surname      0    0.0        0   0.0000    2932   object
# 3       CreditScore      0    0.0        0   0.0000     460    int64
# 4         Geography      0    0.0        0   0.0000       3   object
# 5            Gender      0    0.0        0   0.0000       2   object
# 6               Age      0    0.0        0   0.0000      70    int64
# 7            Tenure      0    0.0      413   0.0413      11    int64
# 8           Balance      0    0.0     3617   0.3617    6382  float64
# 9     NumOfProducts      0    0.0        0   0.0000       4    int64
# 10        HasCrCard      0    0.0     2945   0.2945       2    int64
# 11   IsActiveMember      0    0.0     4849   0.4849       2    int64
# 12  EstimatedSalary      0    0.0        0   0.0000    9999  float64
# ...

# %% [markdown]
# Podemos notar que las columnas `RowNumber`, `CustomerId` y `Surname` deberían ser eliminadas porque son identificadores únicos que no nos aportan información relevante al proyecto.

# %%
dataset = dataset.drop(columns=['RowNumber', 'CustomerId', 'Surname'], axis=1)
dataset
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %% [markdown]
# Notamos que hay columnas que deberían ser booleanas y son int, así que vamos a convertirlas a booleanas

# %%
dataset['IsActiveMember'] = dataset['IsActiveMember'].astype(bool)
dataset['HasCrCard'] = dataset['HasCrCard'].astype(bool)
dataset["Exited"] = dataset["Exited"].astype(bool)

# %% [markdown]
# Luego con la variable `NumOfProducts`, vamos a transformarla de int a object

# %%
dataset["NumOfProducts"] = dataset["NumOfProducts"].astype(str)

# %%
dataset.dtypes
# Out:
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts       object
# HasCrCard             bool
# IsActiveMember        bool
# EstimatedSalary    float64
# Exited                bool
# dtype: object

# %% [markdown]
# Guardamos el dataset adaptado

# %%
dataset.to_csv("../datasets/adapted_data/Churn_Modelling_adapted.csv", index=False)
