# %%
import pandas as pd
import numpy as np
from funpymodeling import status, freq_tbl
import pickle

# %%
dataset = pd.read_csv("../datasets/adapted_data/Churn_Modelling_adapted.csv")
dataset
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %%
status(dataset)
# Out:
#            variable  q_nan  p_nan  q_zeros  p_zeros  unique     type
# 0       CreditScore      0    0.0        0   0.0000     460    int64
# 1         Geography      0    0.0        0   0.0000       3   object
# 2            Gender      0    0.0        0   0.0000       2   object
# 3               Age      0    0.0        0   0.0000      70    int64
# 4            Tenure      0    0.0      413   0.0413      11    int64
# 5           Balance      0    0.0     3617   0.3617    6382  float64
# 6     NumOfProducts      0    0.0        0   0.0000       4    int64
# 7         HasCrCard      0    0.0     2945   0.2945       2     bool
# 8    IsActiveMember      0    0.0     4849   0.4849       2     bool
# 9   EstimatedSalary      0    0.0        0   0.0000    9999  float64
# 10           Exited      0    0.0     7963   0.7963       2     bool

# %%
dataset["NumOfProducts"] = dataset["NumOfProducts"].astype(str)

# %% [markdown]
# ### One-Hot Encoding

# %%
data_ohe = pd.get_dummies(dataset)
data_ohe
# Out:
#       CreditScore  Age  Tenure    Balance  HasCrCard  IsActiveMember  \
# 0             619   42       2       0.00       True            True
# 1             608   41       1   83807.86      False            True
# 2             502   42       8  159660.80       True           False
# 3             699   39       1       0.00      False           False
# 4             850   43       2  125510.82       True            True
# ...           ...  ...     ...        ...        ...             ...
# 9995          771   39       5       0.00       True           False
# 9996          516   35      10   57369.61       True            True
# 9997          709   36       7       0.00      False            True
# 9998          772   42       3   75075.31       True           False
# 9999          792   28       4  130142.79       True           False
#
#       EstimatedSalary  Exited  Geography_France  Geography_Germany  \
# 0           101348.88    True              True              False
# ...

# %%
data_ohe_without_exited = data_ohe.drop("Exited", axis=1)
data_ohe_without_exited
# Out:
#       CreditScore  Age  Tenure    Balance  HasCrCard  IsActiveMember  \
# 0             619   42       2       0.00       True            True
# 1             608   41       1   83807.86      False            True
# 2             502   42       8  159660.80       True           False
# 3             699   39       1       0.00      False           False
# 4             850   43       2  125510.82       True            True
# ...           ...  ...     ...        ...        ...             ...
# 9995          771   39       5       0.00       True           False
# 9996          516   35      10   57369.61       True            True
# 9997          709   36       7       0.00      False            True
# 9998          772   42       3   75075.31       True           False
# 9999          792   28       4  130142.79       True           False
#
#       EstimatedSalary  Geography_France  Geography_Germany  Geography_Spain  \
# ...

# %% [markdown]
# ### Guardamos ohe categories

# %%
with open("../ohe_categories_without_exited.pickle", "wb") as handle:
    pickle.dump(data_ohe_without_exited.columns, handle, protocol = pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### Guardar el dataset

# %%
filename = "../datasets/processed_data/cleaned_data.csv"
data_ohe.to_csv(filename, index = False)
